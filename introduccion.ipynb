# %%
variable = 1
# comments
"""
Esto es un comentario
"""
# Out:
# '\nEsto es un comentario\n'

# %%
variable = 1

if(variable == 1):
    print("Hello world")
# Out:
# Hello world

# %%
n = 3.5
print(type(n))
n = "Hola mundo"
print(type(n))
# Out:
# <class 'float'>
# <class 'str'>

# %%
print(n)
# Out:
# 3.5

# %%
type(n)
# Out:
# float

# %%
import constantes

precio = 25
precio_final = precio + (precio*constantes.IVA)

# %%
print(precio_final)
# Out:
# 28.75
