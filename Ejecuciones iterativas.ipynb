# %%
numero = 5
contador = 0

while(contador < 5):
    contador += 1
    print(contador)
    if(contador == 4):
        contador += 1 
else:
    print("He terminado!")
# Out:
# 1
# 2
# 3
# 4
# He terminado!

# %%
lista = [4,5,6]

for variable in lista:
    print(variable)
else:
    print("He terminado")
# Out:
# 4
# 5
# 6
# He terminado

# %%
cadena = "Hola mundo"
for caracter in cadena:
    print(caracter)
# Out:
# H
# o
# l
# a
#
# m
# u
# n
# d
# o

# %%
lista = [4, "hola mundo", True]
for variable in lista:
    print(variable)
    print(type(variable))
else: 
    print("He terminado")
# Out:
# 4
# <class 'int'>
# hola mundo
# <class 'str'>
# True
# <class 'bool'>
# He terminado

# %%
cadena = "Hola mundo"
# Este for salta cada 2 caracteres
for caracter in range(0,len(cadena), 2):
    print(cadena[caracter])
# Out:
# H
# l
#
# u
# d

# %%
cadena = "Hola mundo"
for caracter in cadena:
    if(caracter == " "):
        continue
    print(caracter)
# Out:
# H
# o
# l
# a
# m
# u
# n
# d
# o

# %%
cadena = "Hola mundo"
iterador = iter(cadena)
next(iterador)
# Out:
# 'H'

# %%
next(iterador)
# Out:
# 'o'

# %%
cadena = "Hola mundo"
iterador = iter(cadena)

for caracter in range(0,len(cadena)):
    print(next(iterador))
# Out:
# H
# o
# l
# a
#
# m
# u
# n
# d
# o

# %%
cadena = "Hola mundo"

for i in range(0,3):
    for variable in cadena:
        print(variable)
    print(" ")
# Out:
# H
# o
# l
# a
#
# m
# u
# n
# d
# o
#
# H
# o
# l
# a
#
# m
# u
# n
# d
# o
#
# H
# o
# l
# a
#
# m
# u
# n
# d
# o
