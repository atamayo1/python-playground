# %%
import calculadora_promedios as calc

calc.main()
# Out:
# Introduce el nombre de la materia:  Matematicas
# Introduce la calificación (0 a 10):  4
# ¿Agregar otra materia? (s/n):  s
# Introduce el nombre de la materia:  Sociales
# Introduce la calificación (0 a 10):  7
# ¿Agregar otra materia? (s/n):  s
# Introduce el nombre de la materia:  Fisica
# Introduce la calificación (0 a 10):  6
# ¿Agregar otra materia? (s/n):  n
# Promedio: 5.67
# Materias aprobadas:
# - Sociales 7.0
# - Fisica 6.0
# Materias reprobadas:
# - Matematicas 4.0
# Mejor calificación:
# Sociales 7.0
# Peor calificación:
# Matematicas 4.0
