# %%
def funcion ():
    return "Hola mundo"

# %%
funcion()
# Out:
# 'Hola mundo'

# %%
def cuadrado (numero, cuad):
    return(numero**cuad)

# %%
cuadrado(5,3)
# Out:
# 125

# %%
def funcion2(*args):
    result = 0
    for i in args:
        result += i
        return result

# %%
funcion2(1,2,5,8,16)
# Out:
# 1

# %%
def funcion3(**args):
    for argument in args:
        print(argument,'->', args[argument])

# %%
funcion3(arg=1, arg2="Hola Mundo")
# Out:
# arg -> 1
# arg2 -> Hola Mundo

# %%
def devuelveVariosValores():
    return 1,2,"hola mundo"

# %%
x,v,w = devuelveVariosValores()

# %%
v
# Out:
# 2

# %%
x
# Out:
# 1

# %%
w
# Out:
# 'hola mundo'

# %%
def cuadrado (numero):
    """
    Esta función nos permite elevar al cuadrado un numero
    
    Argumentos:
    numero de tipo numero
    """
    return numero**2

# %%
help(cuadrado)
# Out:
# Help on function cuadrado in module __main__:
#
# cuadrado(numero)
#     Esta función nos permite elevar al cuadrado un numero
#
#     Argumentos:
#     numero de tipo numero
