# %%
import pandas as pd

# %%
serie = pd.Series([1,2,4,5,6], index = ['a','b','c','d','e'])

# %%
serie
# Out:
# a    1
# b    2
# c    4
# d    5
# e    6
# dtype: int64

# %%
diccionario = {'a':5, 'b':6, 'c':89, 'd':97}

# %%
serie1 = pd.Series(diccionario)

# %%
serie1
# Out:
# a     5
# b     6
# c    89
# d    97
# dtype: int64

# %%
serie1['d']
# Out:
# np.int64(97)

# %%
serie1[2:]
# Out:
# c    89
# d    97
# dtype: int64

# %%
serie1.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
serie1.values
# Out:
# array([ 5,  6, 89, 97])

# %%
resultado = serie1 + serie

# %%
resultado
# Out:
# a      6.0
# b      8.0
# c     93.0
# d    102.0
# e      NaN
# dtype: float64

# %%
serie1 * 10
# Out:
# a     50
# b     60
# c    890
# d    970
# dtype: int64

# %%
import numpy as np

# %%
np.sqrt(serie1)
# Out:
# a    2.236068
# b    2.449490
# c    9.433981
# d    9.848858
# dtype: float64

# %%
dic1 = {'columna1': pd.Series([1,2,4,5,6], index = ['a','b','c','d','e']), 'columna 2': pd.Series([8,9,10,11], index = ['a','b','c','d'])}

# %%
dataframe = pd.DataFrame(dic1)

# %%
dataframe
# Out:
#    columna1  columna 2
# a         1        8.0
# b         2        9.0
# c         4       10.0
# d         5       11.0
# e         6        NaN

# %%
lista = [{'a': 1, 'b': 5, 'c': 7}, {'c': 1, 'h': 5, 'b': 7}]

# %%
dataframe1 = pd.DataFrame(lista)

# %%
dataframe1
# Out:
#      a  b  c    h
# 0  1.0  5  7  NaN
# 1  NaN  7  1  5.0

# %%
dataframe1['b']
# Out:
# 0    5
# 1    7
# Name: b, dtype: int64

# %%
dataframe1['t'] = pd.Series([5,2], index = [0,1])

# %%
dataframe1
# Out:
#      a  b  c    h  t
# 0  1.0  5  7  NaN  5
# 1  NaN  7  1  5.0  2

# %%
dataframe['columna 3'] = pd.Series([1,2,4,5,6], index = ['a','b','c','d','e'])

# %%
dataframe
# Out:
#    columna1  columna 2  columna 3
# a         1        8.0          1
# b         2        9.0          2
# c         4       10.0          4
# d         5       11.0          5
# e         6        NaN          6

# %%
del dataframe['columna1']

# %%
dataframe
# Out:
#    columna 2  columna 3
# a        8.0          1
# b        9.0          2
# c       10.0          4
# d       11.0          5
# e        NaN          6

# %%
dataframe.loc['b']
# Out:
# columna 2    9.0
# columna 3    2.0
# Name: b, dtype: float64

# %%
dataframe.iloc[1]
# Out:
# columna 2    9.0
# columna 3    2.0
# Name: b, dtype: float64

# %%
dataframe.iloc[3]
# Out:
# columna 2    11.0
# columna 3     5.0
# Name: d, dtype: float64

# %%
filtro = np.array([True, False, True, False, True])

# %%
dataframe[filtro]
# Out:
#    columna 2  columna 3
# a        8.0          1
# c       10.0          4
# e        NaN          6

# %%
dataframe.T
# Out:
#              a    b     c     d    e
# columna 2  8.0  9.0  10.0  11.0  NaN
# columna 3  1.0  2.0   4.0   5.0  6.0

# %%
dataframe.sort_values(by='columna 2')
# Out:
#    columna 2  columna 3
# a        8.0          1
# b        9.0          2
# c       10.0          4
# d       11.0          5
# e        NaN          6

# %%
dataframe.sort_values(by='columna 3', ascending = False)
# Out:
#    columna 2  columna 3
# e        NaN          6
# d       11.0          5
# c       10.0          4
# b        9.0          2
# a        8.0          1

# %%
dataframe.groupby('columna 2').count()
# Out:
#            columna 3
# columna 2
# 8.0                1
# 9.0                1
# 10.0               1
# 11.0               1

# %%
dataframe.apply(lambda item: item['columna 2']<35 and item['columna 3'] == 2, axis = 1)
# Out:
# a    False
# b     True
# c    False
# d    False
# e    False
# dtype: bool

# %%
dataframe.describe()
# Out:
#        columna 2  columna 3
# count   4.000000   5.000000
# mean    9.500000   3.600000
# std     1.290994   2.073644
# min     8.000000   1.000000
# 25%     8.750000   2.000000
# 50%     9.500000   4.000000
# 75%    10.250000   5.000000
# max    11.000000   6.000000

# %%
passengers = pd.read_csv('titanic.csv')
# Out:
#    PassengerId  Survived  Pclass                            Name     Sex  \
# 0            1         0       3         Braund, Mr. Owen Harris    male
# 1            2         1       1      Cumings, Mrs. John Bradley  female
# 2            3         1       3          Heikkinen, Miss. Laina  female
# 3            4         1       1    Futrelle, Mrs. Jacques Heath  female
# 4            5         0       3        Allen, Mr. William Henry    male
# 5            6         0       3                Moran, Mr. James    male
# 6            7         0       1         McCarthy, Mr. Timothy J    male
# 7            8         1       3  Palsson, Master. Gosta Leonard    male
# 8            9         1       3           Johnson, Mrs. Oscar W  female
# 9           10         0       2           Nasser, Mrs. Nicholas  female
#
#     Age     Fare Embarked
# 0  22.0   7.2500        S
# 1  38.0  71.2833        C
# 2  26.0   7.9250        S
# 3  35.0  53.1000        S
# 4  35.0   8.0500        S
# ...
