# %%
import math

math.fabs(-15836)
# Out:
# 15836.0

# %%
math.gcd(15,5)
# Out:
# 5

# %%
math.floor(60.30)
# Out:
# 60

# %%
math.ceil(60.30)
# Out:
# 61

# %%
math.factorial(5)
# Out:
# 120

# %%
math.trunc(60)
# Out:
# 60

# %%
math.sin(math.pi/4)
# Out:
# 0.7071067811865475

# %%
math.cos(math.pi/2)
# Out:
# 6.123233995736766e-17

# %%
math.tan(math.pi/2)
# Out:
# 1.633123935319537e+16

# %%
math.asin(1)
# Out:
# 1.5707963267948966

# %%
math.acos(1)
# Out:
# 0.0

# %%
math.atan(1)
# Out:
# 0.7853981633974483

# %%
math.hypot(10,7)
# Out:
# 12.206555615733702

# %%
math.log(12,2)
# Out:
# 3.5849625007211565

# %%
math.log2(12)
# Out:
# 3.584962500721156

# %%
math.log10(12)
# Out:
# 1.0791812460476249

# %%
math.pow(5,2)
# Out:
# 25.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import sys

# %%
# !python test.py "Hola mundo" 35
# Out:
# ['test.py', 'Hola mundo', '35']

# %%
sys.executable
# Out:
# '/opt/anaconda3/bin/python'

# %%
sys.version
# Out:
# '3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:11:29) [Clang 20.1.8 ]'

# %%
sys.platform
# Out:
# 'darwin'

# %%
sys.getdefaultencoding()
# Out:
# 'utf-8'

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground'

# %%
os.mkdir('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/nueva-carpeta')

# %%
os.rmdir('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/nueva-carpeta-2')

# %%
os.remove('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.py')

# %%
os.rename('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/nueva-carpeta','/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/nueva-carpeta-2')

# %%
import os.path

# %%
os.mkdir('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.py')

# %%
os.path.abspath('./test.py')
# Out:
# '/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.py'

# %%
os.path.basename('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.py')
# Out:
# 'test.py'

# %%
os.path.exists('nueva-carpeta')
# Out:
# True

# %%
os.path.isfile('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.py')
# Out:
# False

# %%
os.path.isfile('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/test.text')
# Out:
# True

# %%
os.path.isdir('/Users/anthonytamayoortega/Documents/BackendProjects/Python/python-playground/nueva-carpeta')
# Out:
# True

# %%
import random

# %%
random.randint(5,9)
# Out:
# 8

# %%
random.choice(['hola', 3, 5, True])
# Out:
# 5

# %%
lista = ['hola', 3, 5, True]
random.shuffle(lista)
lista
# Out:
# [3, True, 5, 'hola']

# %%
random.sample(lista, 2)
# Out:
# [True, 5]
