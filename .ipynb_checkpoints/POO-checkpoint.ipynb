# %%
class Libro:
    titulo = "Don Quijote de la Mancha"
    autor = "Miguel de Cervantes"
    isbn = "0987-7489"
    editorial = "Una editorial"
    paginas = 987
    edicion = 34

    def __init__(self, titulo, autor, isbn, editorial, paginas, edicion):
        self.titulo = titulo
        self.autor = autor
        self.isbn = isbn
        self.editorial = editorial
        self.paginas = paginas
        self.edicion = edicion

    def modificaEdicion(self, sumaEdicion):
        self.edicion += sumaEdicion

# %%
miLibro = Libro("El principito", "Anonimo", "0658-7859", "Mi editorial", 25, 1)
miLibro2 = Libro("Crepusculo", "Stephania Mayer", "568954654", "Editorial 2", 250, 5)

# %%
print(miLibro.titulo)
print(miLibro2.titulo)
# Out:
# El principito
# Crepusculo

# %%
miLibro.isbn
# Out:
# '0658-7859'

# %%
miLibro.edicion
# Out:
# 1

# %%
miLibro.modificaEdicion(5)

# %%
miLibro.edicion
# Out:
# 6

# %%
class Persona:
    """
    Clase Persona
    Esta clase cuenta con 4 atributos y un metodo
    """
    def __init__(self, nombre, fechaNacimiento, domicilio):
        self.nombre = nombre
        self.fechaNacimiento = fechaNacimiento
        self.domicilio = domicilio

    def cambiarDomicilio(self, nuevoDomicilio):
        """
        Este metodo cambia el domicilio de la persona
        """
        self.domicilio = nuevoDomicilio

# %%
class Profesor (Persona):
    def __init__(self, nombre, fechaNacimiento, domicilio, identificadorProfesor):
        Persona.__init__(self, nombre, fechaNacimiento, domicilio)
        self.identificadorProfesor = identificadorProfesor

    def modificaIdentificacion(self, nuevaIdentificacion):
        self.identificacion = nuevaIdentificacion

# %%
class Alumno (Persona):
    def __init__(self, nombre, fechaNacimiento, domicilio, calificacion):
        Persona.__init__(self, nombre, fechaNacimiento, domicilio)
        self.calificacion = calificacion

    def calificar (self, nota):
        self.calificacion = nota

# %%
alumno = Alumno("Alejandro", "30/08/1990", "calle inventada 123", 0)

profesor = Profesor("Pepe", "12/07/1975", "Calle inventada2 456", "123456")

# %%
alumno.cambiarDomicilio("inventado 789")

# %%
alumno.domicilio
# Out:
# 'inventado 789'

# %%
profesor.domicilio
# Out:
# 'Calle inventada2 456'

# %%
alumno.calificar(7)

# %%
alumno.calificacion
# Out:
# 7

# %%
help(Persona)
# Out:
# Help on class Persona in module __main__:
#
# class Persona(builtins.object)
#  |  Persona(nombre, fechaNacimiento, domicilio)
#  |
#  |  Clase Persona
#  |  Esta clase cuenta con 4 atributos y un metodo
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, nombre, fechaNacimiento, domicilio)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  cambiarDomicilio(self, nuevoDomicilio)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
help(Persona.cambiarDomicilio)
# Out:
# Help on function cambiarDomicilio in module __main__:
#
# cambiarDomicilio(self, nuevoDomicilio)
#     Este metodo cambia el domicilio de la persona
