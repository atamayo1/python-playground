# %%
list = []

for i in range(1, 11):
    list.append(i**2)

# %%
list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
list2 = []

list2 = [i**2 for i in range(1,11) if i**2>16]

# %%
list2
# Out:
# [25, 36, 49, 64, 81, 100]

# %%
list3 = {"clave" + str(i): i**2 for i in range(1,11) if i>2}

# %%
list3
# Out:
# {'clave3': 9,
#  'clave4': 16,
#  'clave5': 25,
#  'clave6': 36,
#  'clave7': 49,
#  'clave8': 64,
#  'clave9': 81,
#  'clave10': 100}

# %%
conjunto = {i**2 for i in range(1,11) if i<4}

# %%
conjunto
# Out:
# {1, 4, 9}
